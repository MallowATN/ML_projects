# %%
import os
import time
import datetime
import selenium.webdriver as webdriver
import chromedriver_binary
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException, NoSuchElementException, ElementNotInteractableException
from bs4 import BeautifulSoup
import pandas as pd

# %%
def xpath_element(xpath):
    try:
        element = driver.find_element(By.XPATH, xpath)
    except NoSuchElementException:
        element = []
    return element

# %%
def main(ticker):
    url = 'https://coinmarketcap.com/currencies/' + ticker + '/historical-data/'
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0'
    PATH = 'C:\Program Files\Mozilla Firefox'
    s=Service('C:\Program Files\Mozilla Firefox\geckodriver.exe')
    driver = webdriver.Firefox(service=s)
    driver.implicitly_wait(5)
    driver.get(url)

# %%
url = 'https://coinmarketcap.com/currencies/ethereum/historical-data/'
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0'
PATH = 'C:\Program Files\Mozilla Firefox'
s=Service('C:\Program Files\Mozilla Firefox\geckodriver.exe')
driver = webdriver.Firefox(service=s)
driver.implicitly_wait(5)
driver.get(url)

xpath = '//*[@id="__next"]/div[1]/div[1]/div[2]/div/div[3]/div/div/div[2]'
xpath_element(xpath)
time.sleep(2)
output_path = 'testing.xlsx'
xlwriter = pd.ExcelWriter(output_path)
load_more = True
while load_more:
        try:
            driver.find_element(by=By.CLASS_NAME, value="x0o17e-0 DChGS").click()
            time.sleep(1)
        except ElementNotInteractableException:
            load_more=False
df = pd.read_html(driver.page_source)[0]
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [21], in <cell line: 15>()
#      15 while load_more:
#      16         try:
# ---> 17             driver.find_element(by=By.CLASS_NAME, value="x0o17e-0 DChGS").click()
#      18             time.sleep(1)
#      19         except ElementNotInteractableException:
#
# File ~\anaconda3\envs\mytfenv\lib\site-packages\selenium\webdriver\remote\webdriver.py:1248, in WebDriver.find_element(self, by, value)
#    1245     by = By.CSS_SELECTOR
#    1246     value = '[name="%s"]' % value
# -> 1248 return self.execute(Command.FIND_ELEMENT, {
#    1249     'using': by,
#    1250     'value': value})['value']
#
# File ~\anaconda3\envs\mytfenv\lib\site-packages\selenium\webdriver\remote\webdriver.py:425, in WebDriver.execute(self, driver_command, params)
#     423 response = self.command_executor.execute(driver_command, params)
# ...

# %%
df
# Out:
#             Date      Open*       High        Low    Close**           Volume  \
# 0   May 07, 2022  $2,694.99  $2,696.65  $2,599.52  $2,636.09  $13,369,276,367
# 1   May 06, 2022  $2,748.93  $2,754.84  $2,645.34  $2,694.98  $21,027,599,270
# 2   May 05, 2022  $2,940.23  $2,948.96  $2,704.92  $2,749.21  $22,642,925,048
# 3   May 04, 2022  $2,783.13  $2,956.69  $2,779.27  $2,940.64  $18,186,749,944
# 4   May 03, 2022  $2,857.15  $2,859.19  $2,762.12  $2,783.48  $13,026,093,219
# ..           ...        ...        ...        ...        ...              ...
# 56  Mar 12, 2022  $2,559.66  $2,606.44  $2,559.13  $2,574.75   $6,532,996,574
# 57  Mar 11, 2022  $2,608.27  $2,664.56  $2,534.69  $2,559.56  $12,382,419,582
# 58  Mar 10, 2022  $2,729.12  $2,729.12  $2,566.19  $2,608.05  $13,292,477,213
# 59  Mar 09, 2022  $2,577.17  $2,761.80  $2,573.66  $2,729.78  $14,173,665,398
# 60  Mar 08, 2022  $2,497.72  $2,618.17  $2,489.76  $2,576.75  $13,922,922,903
#
#           Market Cap
# ...

# %%
ticker = ['xrp','bitcoin','ethereum','litecoin','avalanche','ravencoin','cardano','solana','dogecoin']
