# %%
import numpy as np
import pandas as pd

# %%
xlsx = pd.ExcelFile('TV_Crypto_Prices.xlsx')

# %%
df1 = pd.read_excel(xlsx,sheet_name='Overview')
df1
# Out:
#                  NameNo matches   Mkt Cap FD Mkt Cap          Last  \
# 0                       Bitcoin  683.819B   754.508B  35928.970000
# 1                      Ethereum  324.008B   324.008B   2685.010000
# 2                        Tether   83.209B    85.685B      0.999660
# 3                  Binance Coin   61.996B    62.695B    379.700000
# 4                      USD Coin   48.611B    48.611B      1.000000
# ..                          ...       ...        ...           ...
# 817  Square tokenized stock FTX         0          0     95.347000
# 818                      MINDOL         0     2.019M      0.008411
# 819                      Amoveo         0   276.618K      3.960838
# 820                   VeriBlock         0     3.785M      0.001802
# 821             Quantfury Token         0     1.206B     12.057000
#
#     Avail Coins Total Coins Traded Vol    Chg %
# 0       19.033M         21M    38.807B   −1.66%
# 1      120.673M    120.673M    21.694B   −2.24%
# ...

# %%
df2 = pd.read_excel(xlsx, sheet_name='Performance')
df2
# Out:
#                                      NameNo matches   Chg % 1W CHG % 1M CHG %  \
# 0                                           Bitcoin  −1.65%   −6.64%   −4.54%
# 1                                          Ethereum  −2.24%   −4.97%   −1.60%
# 2                                            Tether   0.02%   −0.04%   −0.02%
# 3                                      Binance Coin   0.37%   −2.64%    0.61%
# 4                                          USD Coin   0.00%    0.00%   −0.01%
# ..                                              ...     ...      ...      ...
# 817  AMC Entertainment Holdings tokenized stock FTX  −4.65%   −8.41%   −8.41%
# 818                                      CardWallet  12.67%    3.21%    3.21%
# 819                                   Simbcoin Swap  20.53%   39.92%   39.92%
# 820                      Hub - Human Trust Protocol  21.69%    8.30%    1.07%
# 821                         Brazilian Digital Token   0.35%   −0.58%   −1.21%
#
# ...

# %%
df3 = pd.read_excel(xlsx, sheet_name='Oscillators')
df3
# Out:
#           NameNo matches Oscillators Rating      ADX                AO  \
# 0                Bitcoin            Neutral  27.56 N  −2800.25685294 S
# 1               Ethereum            Neutral  25.25 N   −228.96514706 N
# 2                 Tether            Neutral  89.94 N     −0.00058221 N
# 3           Binance Coin            Neutral  20.99 N    −22.66411765 N
# 4               USD Coin            Neutral  21.94 N      0.00012412 N
# ..                   ...                ...      ...               ...
# 817       U  UniX Gaming                Buy  18.64 N     −0.04134774 N
# 818  IQONIQ FanEcoSystem                Buy  25.56 N      0.00012716 N
# 819              Moderna               Sell  50.89 N    −22.66692353 S
# 820               Pastel            Neutral  29.96 N       0.0005982 N
# 821             1  1peco                Buy  26.83 N     −0.24498836 N
#
#                ATR      CCI20        MACD Level     MACD Signal  \
# ...

# %%
df4 = pd.read_excel(xlsx, sheet_name = 'Trend-Following')
df4
# Out:
#     NameNo matches Moving Averages Rating          Last          SMA20  \
# 0          Bitcoin            Strong Sell  35932.350000   39158.3145 S
# 1         Ethereum            Strong Sell   2684.760000    2902.6525 S
# 2           Tether            Strong Sell      0.999820    1.0000345 S
# 3     Binance Coin            Strong Sell    379.600000      397.955 S
# 4         USD Coin            Strong Sell      0.999900     0.999955 S
# ..             ...                    ...           ...            ...
# 817            Nio            Strong Sell     14.890000     18.13775 S
# 818       Etheroll            Strong Sell      0.266821   0.46536205 S
# 819          Pearl                    Buy     27.236965  23.91808903 B
# 820      Silverway            Strong Sell     20.657000      22.5935 S
# 821   HeroesTD CGC                   Sell      6.512000      6.43655 B
#
#              SMA50           SMA200             BB Up            BB Low
# ...

# %%
df1.T
# Out:
#                      0         1        2             3         4         5    \
# NameNo matches   Bitcoin  Ethereum   Tether  Binance Coin  USD Coin       HEX
# Mkt Cap         683.819B  324.008B  83.209B       61.996B   48.611B   31.664B
# FD Mkt Cap      754.508B  324.008B  85.685B       62.695B   48.611B  115.682B
# Last            35928.97   2685.01  0.99966         379.7       1.0  0.182596
# Avail Coins      19.033M  120.673M  83.237B      163.277M   48.611B  173.411B
# Total Coins          21M  120.673M  85.714B      165.117M   48.611B  633.543B
# Traded Vol       38.807B   21.694B   76.04B        1.893B    5.536B   23.736M
# Chg %             −1.66%    −2.24%    0.02%         0.40%     0.01%     2.86%
#
#                     6         7          8        9    ...               812  \
# NameNo matches      XRP    Solana      Terra  Cardano  ...  The Coop Network
# Mkt Cap         28.888B   27.318B    26.933B  26.283B  ...                 0
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>
