# %%
import cv2
import mediapipe as mp
import time

# %%
cap = cv2.VideoCapture(0)

# %%
mpHands = mp.solutions.hands
hands = mpHands.Hands()
mpDraw = mp.solutions.drawing_utils

pTime = 0
cTime = 0

# %%
while True:
    success, img = cap.read()
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)
    # print(results.multi_hand_landmarks)
    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks: # landmark will give us x,y coordinates
            for id, lm in enumerate(handLms.landmark): #find the index
                # print(id, lm)
                h, w, c = img.shape
                cx, cy = int(lm.x*w), int(lm.y*h)
                print(id, cx, cy)
                if id == 4: #modify for point positions
                    cv2.circle(img, (cx,cy), 25, (255,0,255),cv2.FILLED)
            mpDraw.draw_landmarks(img, handLms, mpHands.HAND_CONNECTIONS) #draw on RGB image
    
    cTime = time.time()
    fps = 1/(cTime-pTime)
    pTime = cTime
    cv2.putText(img, 'fps: ' +str(int(fps)), (10,70), cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)

    cv2.imshow('Image', img)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# 0 254 890
# 1 180 841
# 2 151 750
# 3 150 671
# 4 138 603
# 5 231 660
# 6 245 569
# 7 253 510
# 8 260 460
# 9 291 668
# 10 313 571
# 11 326 506
# 12 335 452
# 13 338 696
# 14 372 607
# 15 392 551
# 16 405 500
# 17 379 739
# 18 411 673
# 19 431 631
# 20 447 590
# 0 260 884
# 1 193 824
# 2 169 734
# 3 169 655
# 4 154 591
# 5 238 642
# 6 247 550
# 7 254 498
# 8 262 452
# 9 294 647
# 10 314 552
# 11 326 493
# 12 334 443
# 13 340 671
# 14 368 586
# 15 384 532
# 16 395 484
# 17 379 710
# 18 407 647
# 19 423 605
# 20 435 567
# 0 259 889
# 1 192 827
# 2 167 737
# 3 167 657
# 4 154 589
# 5 240 641
# 6 249 551
# 7 254 498
# 8 262 452
# 9 295 647
# 10 314 552
# 11 325 494
# 12 334 445
# 13 340 672
# 14 368 586
# 15 385 533
# 16 398 486
# 17 379 711
# 18 407 650
# 19 424 609
# 20 438 570
# 0 265 869
# 1 202 801
# 2 179 715
# 3 178 638
# 4 169 573
# 5 247 629
# 6 256 541
# 7 262 491
# 8 271 445
# 9 299 636
# 10 317 542
# 11 328 487
# 12 338 439
# 13 342 657
# 14 368 573
# 15 382 521
# 16 392 475
# ...
